# %%
import pandas as pd
import numpy as np
import seaborn as sns

def load_and_process(csv_file_path):

    # Method Chain 1 (Load data and deal with missing data, drop unnecessary columns,and convert all strings to lowercase)

    df1 = (
          pd.read_csv(csv_file_path)
          .dropna(axis=1, how='all')                        #drops the neighbourhood column where all whole column is empty.
          .drop(['last_review','reviews_per_month'],axis=1)
          .applymap(lambda x:x.lower() if type(x) == str else x)
      )
    
    #Using boxplot and scatter plots, the outliers are determined.
    
    #sns.boxplot(x=df1['minimum_nights'])
    #sns.scatterplot(x='price',y='minimum_nights',data = df1)
    #sns.boxplot(x=df1['price'])
    
    df1.loc[df1['minimum_nights']>400, 'minimum_nights'] = df1['minimum_nights'].mean()
    df1.loc[df1['price']>150000,'price'] = df1['price'].mean()
    

    return df1

# %%
df=load_and_process('../../Data/raw/listings.csv')
df
# Out:
#              id                                               name   host_id  \
# 0          3191                            malleson garden cottage      3754
# 1         15007                                   blaauwberg house     59072
# 2         15077                  top relaxed beach living in style     59342
# 3         15180                          the melkbaai - beachfront     59663
# 4         15199                            self catering apartment     59694
# ...         ...                                                ...       ...
# 19272  47226603         waterfall 2 bedroom apartment in camps bay   6269301
# 19273  47226853         tranquil garden cottage with fast internet   3374257
# 19274  47230584       quaint mountain retreat above boulders beach  16229677
# 19275  47231253                    heide acc. in serengeti complex  73013529
# 19276  47232967  gorgeous, stylish apartment in heart of sea point  25991174
#
#                 host_name neighbourhood   latitude  longitude  \
# 0                brigitte       ward 57 -33.947390  18.476000
# 1                    dirk       ward 23 -33.800010  18.460630
# 2                   georg        ward 4 -33.858120  18.490430
# 3                  heinri       ward 83 -34.111240  18.823490
# 4                   alexa      ward 115 -33.910440  18.412390
# ...                   ...           ...        ...        ...
# 19272                lisa       ward 54 -33.963088  18.375922
# 19273               diana       ward 74 -34.045456  18.366974
# 19274  anthony and juliet       ward 61 -34.206961  18.452896
# 19275              engela       ward 21 -33.878198  18.644850
# 19276              aubrey       ward 54 -33.921815  18.384868
#
#              room_type   price  minimum_nights  number_of_reviews  \
# 0      entire home/apt   497.0             3.0                 54
# 1      entire home/apt  4873.0             2.0                 28
# 2         private room  1692.0             5.0                  5
# 3      entire home/apt   580.0             2.0                  0
# 4      entire home/apt  2500.0            14.0                  2
# ...                ...     ...             ...                ...
# 19272  entire home/apt  3074.0             3.0                  0
# 19273  entire home/apt   671.0             4.0                  0
# 19274  entire home/apt   559.0             2.0                  0
# 19275  entire home/apt   743.0             2.0                  0
# 19276  entire home/apt   800.0             2.0                  0
#
#        calculated_host_listings_count  availability_365
# 0                                   1               327
# 1                                   6               268
# 2                                   5               335
# 3                                   1                 0
# 4                                   1               365
# ...                               ...               ...
# 19272                              29               358
# 19273                               5               358
# 19274                               2                82
# 19275                               2                82
# 19276                               5               365
#
# [19277 rows x 13 columns]

# %% [markdown]
# # EDA

# %% [markdown]
# The dataset contains the data regarding the **Airbnb** loacted in Dublin, Ireland.

# %%
df.shape
# Out:
# (19277, 13)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19277 entries, 0 to 19276
# Data columns (total 13 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              19277 non-null  int64
#  1   name                            19277 non-null  object
#  2   host_id                         19277 non-null  int64
#  3   host_name                       19276 non-null  object
#  4   neighbourhood                   19277 non-null  object
#  5   latitude                        19277 non-null  float64
#  6   longitude                       19277 non-null  float64
#  7   room_type                       19277 non-null  object
#  8   price                           19277 non-null  float64
#  9   minimum_nights                  19277 non-null  float64
#  10  number_of_reviews               19277 non-null  int64
#  11  calculated_host_listings_count  19277 non-null  int64
#  12  availability_365                19277 non-null  int64
# dtypes: float64(4), int64(5), object(4)
# memory usage: 1.9+ MB

# %%
df.describe()
# Out:
#                  id       host_id      latitude     longitude          price  \
# count  1.927700e+04  1.927700e+04  19277.000000  19277.000000   19277.000000
# mean   2.646915e+07  1.072429e+08    -33.961674     18.478327    2855.341702
# std    1.343571e+07  1.006227e+08      0.101449      0.128176    6633.070469
# min    3.191000e+03  3.754000e+03    -34.264400     18.319410     122.000000
# 25%    1.567609e+07  2.603210e+07    -34.026820     18.403250     700.000000
# 50%    2.703828e+07  6.609031e+07    -33.934330     18.438000    1300.000000
# 75%    3.937148e+07  1.656463e+08    -33.910340     18.488430    2650.000000
# max    4.723297e+07  3.813097e+08    -33.516150     18.941040  143000.000000
#
#        minimum_nights  number_of_reviews  calculated_host_listings_count  \
# count    19277.000000       19277.000000                    19277.000000
# mean         4.133328          15.403901                        9.669503
# std         13.539279          31.417941                       28.276847
# min          1.000000           0.000000                        1.000000
# 25%          1.000000           0.000000                        1.000000
# 50%          2.000000           3.000000                        2.000000
# 75%          3.000000          15.000000                        5.000000
# max        365.000000         463.000000                      225.000000
#
#        availability_365
# count      19277.000000
# mean         224.794470
# std          132.883235
# min            0.000000
# 25%           90.000000
# 50%          269.000000
# 75%          351.000000
# max          365.000000

# %%
import matplotlib.pyplot as plt 
sns.scatterplot(x='availability_365',y='price',data=df)
# Out:
# <AxesSubplot:xlabel='availability_365', ylabel='price'>

# %% [markdown]
# What is the Maximum Price for a room ?

# %%
df[df['price'] == df['price'].max()]
# Out:
#             id      name    host_id     host_name neighbourhood  latitude  \
# 9046  24349838  sea lion  123002666  in residence       ward 54   -33.931
#
#       longitude        room_type     price  minimum_nights  number_of_reviews  \
# 9046   18.38396  entire home/apt  143000.0             3.0                  0
#
#       calculated_host_listings_count  availability_365
# 9046                              20               353

# %%
df.boxplot(column='price', by='room_type')
# Out:
# <AxesSubplot:title={'center':'price'}, xlabel='room_type'>

# %% [markdown]
# This Indicates that most of the bnb's are entire house or appartmentt

# %%
sns.boxplot(x = 'minimum_nights', y = 'price', data = df) 
sns.set(rc={'figure.figsize':(13.7,10.27)})

# %% [markdown]
# What is the Minimum Price for a room

# %%
df[df['price'] == df['price'].min()]
# Out:
#              id                                 name   host_id host_name  \
# 18857  46692010  affordable beds in awesome location  45512047     clyde
#
#       neighbourhood  latitude  longitude    room_type  price  minimum_nights  \
# 18857       ward 57 -33.93757    18.4719  shared room  122.0             1.0
#
#        number_of_reviews  calculated_host_listings_count  availability_365
# 18857                  1                              12               168
